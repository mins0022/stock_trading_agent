# %%
import pandas as pd
import numpy as np

# %%
stock_df = pd.read_csv('./stock_df/marcap-2014.csv')

# %%
kospi20=['S-Oil','현대차','SK텔레콤','LG전자','이마트','기아차','SK하이닉스','한국전력','대한항공','현대백화점','셀트리온','KB금융','LG화학','아모레퍼시픽','기업은행','현대모비스','대우조선해양','GS건설', 'CJ제일제당','삼성전자']

# %%
kospi20
# Out:
# ['S-Oil',
#  '현대차',
#  'SK텔레콤',
#  'LG전자',
#  '이마트',
#  '기아차',
#  'SK하이닉스',
#  '한국전력',
#  '대한항공',
#  '현대백화점',
#  '셀트리온',
#  'KB금융',
#  'LG화학',
#  '아모레퍼시픽',
#  '기업은행',
#  '현대모비스',
#  '대우조선해양',
#  'GS건설',
#  'CJ제일제당',
#  '삼성전자']

# %%
# for kospi in kospi20:
    stock_df = pd.DataFrame(columns =['Date','Open', 'High', 'Low', 'Close', 'Volume'])
    for year in range(2014,2020):
        temp_df = pd.read_csv('./stock_df/marcap-{}.csv'.format(year))
        temp_df = temp_df[temp_df['Name'] == kospi]
        temp_df = temp_df[['Date','Open', 'High', 'Low', 'Close', 'Volume']]
        stock_df = pd.concat([stock_df, temp_df)
#     stock_df.to_csv('./stock_df/{}_stock.csv'.format(kospi))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date', 'Open', 'High', 'Low', 'Close', 'Volume')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-cf47e424a9b8> in <module>
#       4         temp_df = pd.read_csv('./stock_df/marcap-{}.csv'.format(year))
#       5         temp_df = temp_df[temp_df['Name'] == kospi]
# ----> 6         stock_df = pd.concat([stock_df, temp_df['Date','Open', 'High', 'Low', 'Close', 'Volume']])
#       7 #     stock_df.to_csv('./stock_df/{}_stock.csv'.format(kospi))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date', 'Open', 'High', 'Low', 'Close', 'Volume')

# %%
stock_df = pd.DataFrame(columns =['Date','Open', 'High', 'Low', 'Close', 'Volume'])
for year in range(2014,2020):
    temp_df = pd.read_csv('./stock_df/marcap-{}.csv'.format(year))
    temp_df = temp_df[temp_df['Name'] == kospi]
    temp_df = temp_df[['Date','Open', 'High', 'Low', 'Close', 'Volume']]
    stock_df = pd.concat([stock_df, temp_df])

# %%
stock_df[stock_df['Name'] =='S-Oil']
# Out:
#           Code   Name  Close  Changes  ChagesRatio  Volume       Amount  \
# 29      010950  S-Oil  72500    -1500         -2.0  301161  21813574800
# 2005    010950  S-Oil  71100    -1400         -1.9  390242  27668838700
# 3982    010950  S-Oil  70000    -1100         -1.6  359174  25087813700
# 5958    010950  S-Oil  69700     -300         -0.4  255252  17736790700
# 7934    010950  S-Oil  68000    -1700         -2.4  838126  56563560000
# ...        ...    ...    ...      ...          ...     ...          ...
# 474298  010950  S-Oil  49400    -1600         -3.1  544202  27297978800
# 476317  010950  S-Oil  50800     1400          2.8  451882  22654686800
# 478343  010950  S-Oil  50700     -100         -0.2  256562  13060415800
# 480374  010950  S-Oil  48650    -2050         -4.0  335456  16577818150
# 482410  010950  S-Oil  48400     -250         -0.5  323466  15716404300
#
#          Open   High    Low         Marcap  MarcapRatio     Stocks  \
# 29      74100  74200  71700  8162252420000         0.64  112582792
# 2005    72000  72400  70400  8004636511200         0.63  112582792
# 3982    70500  70800  69600  7880795440000         0.62  112582792
# 5958    69200  69800  69100  7847020602400         0.61  112582792
# 7934    69800  69900  66700  7655629856000         0.60  112582792
# ...       ...    ...    ...            ...          ...        ...
# 474298  51100  51500  49400  5561589924800         0.41  112582792
# 476317  49700  50900  48200  5719205833600         0.42  112582792
# 478343  50600  51500  50500  5707947554400         0.42  112582792
# 480374  50100  50600  48600  5477152830800         0.41  112582792
# 482410  48950  49800  47850  5449007132800         0.41  112582792
#
#         ForeignShares  ForeignRatio  Rank        Date
# 29         51047729.0         45.34    30  2014-01-02
# 2005       51268403.0         45.54    30  2014-01-03
# 3982       51328125.0         45.59    31  2014-01-06
# 5958       51331439.0         45.59    31  2014-01-07
# 7934       51193806.0         45.47    32  2014-01-08
# ...               ...           ...   ...         ...
# 474298     51380863.0         45.64    47  2014-12-23
# 476317     51418491.0         45.67    47  2014-12-24
# 478343     51407117.0         45.66    46  2014-12-26
# 480374     51399528.0         45.65    48  2014-12-29
# 482410     51450025.0         45.70    48  2014-12-30
#
# [245 rows x 17 columns]
