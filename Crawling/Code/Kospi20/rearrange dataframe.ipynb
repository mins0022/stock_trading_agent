# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./selected/S-Oil_df.csv')

# %%
del df['Unnamed: 0']

# %%
sort_df = df.sort_values(by=['Date','Category'])
sort_df = sort_df.reset_index(drop=True)
sort_df
# Out:
#                                     Title        Date  Category
# 0     하나SK카드·외환카드 공동 S-OIL주유소 모바일카드 결제 가능  2014.09.02         3
# 1                에쓰오일, ‘사랑의 송편나눔’ 봉사활동 진행  2014.09.03         3
# 2                에쓰오일, ‘사랑의 송편나눔’ 봉사활동 진행  2014.09.03         4
# 3                에쓰오일, ‘사랑의 송편나눔’ 봉사활동 진행  2014.09.03         8
# 4         올가을 '놈코어(Normcore)' 패션이 유행이라는데…  2014.09.04         4
# ...                                   ...         ...       ...
# 1566   [라이킷픽]이 여름, 다시 설레고 싶다면 포근+강렬 메이크업을  2020.08.25         9
# 1567              S-OIL 순직소방관 유자녀에 장학금 전달  2020.08.26         4
# 1568          강원, 82억원 규모 보일러 패키지 공급계약 해지  2020.08.28         5
# 1569           외국인, 4주만에 '사자' 전환…배터리株 담았다  2020.08.30         5
# 1570                   [e공시 눈에 띄네]코스닥-28일  2020.08.31         5
#
# [1571 rows x 3 columns]

# %%
sort_df['Date'] = sort_df['Date'].astype('datetime64')
type(sort_df['Date'][0])

# %%
na_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
na_df
# Out:
# Empty DataFrame
# Columns: [Title, Date, Category]
# Index: []

# %%
dt_index = pd.date_range(start='20200801', end='20200831')
dt_index
# Out:
# DatetimeIndex(['2020-08-01', '2020-08-02', '2020-08-03', '2020-08-04',
#                '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-08',
#                '2020-08-09', '2020-08-10', '2020-08-11', '2020-08-12',
#                '2020-08-13', '2020-08-14', '2020-08-15', '2020-08-16',
#                '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20',
#                '2020-08-21', '2020-08-22', '2020-08-23', '2020-08-24',
#                '2020-08-25', '2020-08-26', '2020-08-27', '2020-08-28',
#                '2020-08-29', '2020-08-30', '2020-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dt_index_str = str(dt_index)
dt_index_str*10
# Out:
# "DatetimeIndex(['2020-08-01', '2020-08-02', '2020-08-03', '2020-08-04',\n               '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-08',\n               '2020-08-09', '2020-08-10', '2020-08-11', '2020-08-12',\n               '2020-08-13', '2020-08-14', '2020-08-15', '2020-08-16',\n               '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20',\n               '2020-08-21', '2020-08-22', '2020-08-23', '2020-08-24',\n               '2020-08-25', '2020-08-26', '2020-08-27', '2020-08-28',\n               '2020-08-29', '2020-08-30', '2020-08-31'],\n              dtype='datetime64[ns]', freq='D')DatetimeIndex(['2020-08-01', '2020-08-02', '2020-08-03', '2020-08-04',\n               '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-08',\n               '2020-08-09', '2020-08-10', '2020-08-11', '2020-08-12',\n               '2020-08-13', '2020-08-14', '2020-08-15', '2020-08-16',\n               '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20',\n               '2020-08-21'
# ...
