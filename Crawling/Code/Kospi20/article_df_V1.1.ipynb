# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# kospi200_csv = pd.read_csv('KOSPI200_LIST.csv',names = ['index', 'name'], header = None)
# kospi200_csv = kospi200_csv.drop(index = 0)
# kospi200 = kospi200_csv['name']
# kospi200

# %%
# driver = webdriver.Chrome('chromedriver.exe')

# url = 'https://www.asiae.co.kr/'

# # 페이지 이동
# driver.get(url)
# time.sleep(1)

# driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > a').click()
# time.sleep(1)

# %%
# #리스트 추가 # 리스트 목록으로 만들어서 for 문으로 돌리자
# kospi200 = '한라홀딩스'

# %%
# # 검색목록에 넣기
# e = driver.find_element_by_css_selector('#search1')
# e.send_keys(kospi200)
# # 검색버튼 누르기
# driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > div > input').click()

# %%
# #뉴스 목록 선택
# driver.find_element_by_css_selector('#type_news > a > span').click()

# %%
# #검색옵션 선택
# driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lnb > div > a > span").click()
# time.sleep(0.5)
# #기간 필터 클릭
# driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > ul > li.title_tab.tab02 > a > span").click()

# %%
# #기간 입력 및 적용

# inputsDate = driver.find_element_by_css_selector('#sDate')
# inputsDate.send_keys('2014.09.01')
# driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").click()
# time.sleep(0.5)
# inputeDate = driver.find_element_by_css_selector('#eDate')
# inputeDate.send_keys('2020.08.31')
# driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").click()

# time.sleep(0.5)

# driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > div > ul.tcont.tabcont02.on > li.inp_box > div > a").click()

# %%
# #섹션 선택
# driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a').click()

# %%
# driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()

# %%
# article_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
# for section in range(2,12):
#     #섹션 선택
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()
#     time.sleep(0.5)
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_wrap > ul > li:nth-child({}) > a'.format(section)).click()
#     time.sleep(2)
#     #beautifulsoup으로 크롤링하기
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'html.parser')
# #     total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')
# #     total_count = int(total_count.string[2:-1].replace(",",""))
# #     pages = total_count/15
#     leng = soup.body.select('#container > div > div > div > ul')
#     a = leng[0].find_all('li')
#     for i in a:
#         temp_t = i.find('span', class_='tit')
#         temp_d =i.find('span',class_='dt_t')
#         # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#         article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)

# %%
# article_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
# for section in range(5,12):
#     #섹션 선택
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()
#     time.sleep(0.5)
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_wrap > ul > li:nth-child({}) > a'.format(section)).click()
#     time.sleep(2)
#     #beautifulsoup으로 크롤링하기
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'html.parser')
#     total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')
#     total_count = int(total_count.string[2:-1].replace(",",""))
#     pages = total_count//15 +1
#     leng = soup.body.select('#container > div > div > div > ul')
#     a = leng[0].find_all('li')
#     for page in range(2, pages +1):
#         # 1페이지 크롤링
#         for i in a:
#             temp_t = i.find('span', class_='tit')
#             temp_d =i.find('span',class_='dt_t')
#             # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#             article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)
#         # 페이지가 1페이지밖에 없다면 다음 페이지 실행 안함
#         if pages != 1:
#             if int(page) %10 != 1 :
#                 driver.find_element_by_link_text(str(page)).click()
#                 time.sleep(1)
#                 #페이지 변경 후 parser
#                 html = driver.page_source
#                 soup = BeautifulSoup(html, 'html.parser')
#                 for i in a:
#                     temp_t = i.find('span', class_='tit')
#                     temp_d =i.find('span',class_='dt_t')
#                     # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#                     article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)
#             else:
                
#             # 10단위 페이지 이후 다음 버튼 클릭
#                 driver.find_element_by_css_selector('#container > div > div > div > em > div > span > a.btn_paging.btn_next').click()
#                 time.sleep(0.5)
#                 for i in a:
#                     temp_t = i.find('span', class_='tit')
#                     temp_d =i.find('span',class_='dt_t')
#                     # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#                     article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)
#             time.sleep(1)
#             page +=1

# %%
# article_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
# for section in range(2,12):
#     #섹션 선택
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()
#     time.sleep(0.5)
#     driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_wrap > ul > li:nth-child({}) > a'.format(section)).click()
#     time.sleep(2)
#     # total count를 크롤링해서 전체 페이지 수를 체킹
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'html.parser')
#     total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')
#     #섹션에 뉴스가 없을 경우 다음 섹션으로 이동
#     if total_count is None:
#         driver.back()
#         time.sleep(1)
#         article_df = article_df.append({'Title' : None, 'Date':None, 'Category':section}, ignore_index = True)
#         continue
#     #페이지 수 구하기
#     total_count = int(total_count.string[2:-1].replace(",",""))
#     pages = total_count//15 + 1
#     for page in range(pages):
#         # 페이지 바에 대한 셀레늄을 리스트로 가져와서 페이지에 따라 선택
#         page_bar = driver.find_elements_by_css_selector('div.paging_comm > span.inner_paging > *')
#         # 처음 시작할때는 페이지바 안누르기
#         if page != 0:
#             if page%10 != 0:
#                 page_bar[page%10].click()
#             else :
#                 page_bar[len(page_bar)-1].click()
#         time.sleep(0.5)
#         #beautifulsoup으로 크롤링하기
#         html = driver.page_source
#         soup = BeautifulSoup(html, 'html.parser')
#         leng = soup.body.select('#container > div > div > div > ul')
#         a = leng[0].find_all('li')
#         for i in a:
#             temp_t = i.find('span', class_='tit')
#             temp_d =i.find('span',class_='dt_t')
#             # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#             article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)

# %%
# article_df.to_csv('{}_df.csv'.format('한라홀딩스'))

# %%
kospi200_csv = pd.read_csv('KOSPI200_LIST.csv',names = ['index', 'name'], header = None)
kospi200_csv = kospi200_csv.drop(index = 0)
kospi200 = kospi200_csv['name']
kospi200
# Out:
# 1          삼성전자
# 2        SK하이닉스
# 3      삼성바이오로직스
# 4         NAVER
# 5           현대차
#          ...
# 196        고려제강
# 197        한국단자
# 198        한세실업
# 199        대덕전자
# 200     한올바이오파마
# Name: name, Length: 200, dtype: object

# %%
kospi200[4]
# Out:
# 'NAVER'

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.asiae.co.kr/'

kospi20=['삼성전자','현대차','SK텔레콤','LG전자','이마트','기아차','SK하이닉스','한국전력','대한항공',\
'현대백화점','셀트리온','KB금융','LG화학','아모레퍼시픽','기업은행','현대모비스','대우조선해양','GS건설',\
'S-Oil','CJ제일제당']

# 페이지 이동
driver.get(url)
time.sleep(1)

for kospi in kospi20: # 요기 수정해서 크롤링하기!
    #돋보기 버튼 누르기
    driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > a').click()
    time.sleep(1)
    # 검색목록에 넣기
    e = driver.find_element_by_css_selector('#search1')
    e.send_keys(kospi)
    # 검색버튼 누르기
    driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > div > input').click()
    time.sleep(1)
    
    #뉴스 목록 선택
    driver.find_element_by_css_selector('#type_news > a > span').click()
    time.sleep(0.5)
    
    #검색옵션 선택
    driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lnb > div > a > span").click()
    time.sleep(0.5)
    
    #기간 필터 클릭
    driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > ul > li.title_tab.tab02 > a > span").click()
    time.sleep(0.1)
    
    #기간 입력 및 적용
    inputsDate = driver.find_element_by_css_selector('#sDate')
    inputsDate.send_keys('2014.09.01')
    driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").click()
    time.sleep(0.5)
    
    inputeDate = driver.find_element_by_css_selector('#eDate')
    inputeDate.send_keys('2020.08.31')
    driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").click()
    time.sleep(0.5)
    driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > div > ul.tcont.tabcont02.on > li.inp_box > div > a").click()    
    time.sleep(0.1)
    
    #article_df 초기화
    article_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
    for section in range(2,12):
        #섹션 변경시 섹션페이지 잘리는 것을 방지
        if section != 2:
            driver.back()
            time.sleep(1)
        #섹션 선택
        driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()
        time.sleep(0.5)
        driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_wrap > ul > li:nth-child({}) > a'.format(section)).click()
        time.sleep(2)
        # total count를 크롤링해서 전체 페이지 수를 체킹
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')
        #섹션에 뉴스가 없을 경우 다음 섹션으로 이동
        if total_count is None:
            article_df = article_df.append({'Title' : None, 'Date':None, 'Category':section}, ignore_index = True)
            continue
        #페이지 수 구하기
        total_count = int(total_count.string[2:-1].replace(",",""))
        # 페이지가 딱 나눠지게 된다면 +1 을 해주면 안됨
        if total_count%15 != 0:
            pages = total_count//15 + 1
        else :pages = total_count//15
        for page in range(pages):
            # 페이지 바에 대한 셀레늄을 리스트로 가져와서 페이지에 따라 선택
            page_bar = driver.find_elements_by_css_selector('div.paging_comm > span.inner_paging > *')
            # 처음 시작할때는 페이지바 안누르기
            if page != 0:
                if page%10 != 0:
                    page_bar[page%10].click()
                else :
                    page_bar[len(page_bar)-1].click()
            time.sleep(0.5)
            #beautifulsoup으로 크롤링하기
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            leng = soup.body.select('#container > div > div > div > ul')
            a = leng[0].find_all('li')
            for i in a:
                temp_t = i.find('span', class_='tit')
                temp_d =i.find('span',class_='dt_t')
                # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
                article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)
    #파일 csv로 내보내기
    article_df.to_csv('./article_df/{}_df.csv'.format(kospi))     
    #첫페이지로 이동
    driver.find_element_by_css_selector('#wrap > div.header > div.top_head > div > div.menu_ci > h1 > a > img').click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-14-e476a67fd731> in <module>
#      26
#      27     #기간 필터 클릭
# ---> 28     driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > ul > li.title_tab.tab02 > a > span").click()
#      29     time.sleep(0.1)
#      30
#
# ~\anaconda-3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda-3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda-3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda-3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=85.0.4183.121)

# %%
#위 코드가 오류나서 다른 방법으로 시도-유희 
#참고주소 https://wkdtjsgur100.github.io/selenium-does-not-work-to-click/
from selenium.webdriver.common.keys import Keys

# %%
kospi20=['S-Oil','현대차','SK텔레콤','LG전자','이마트','기아차','SK하이닉스','한국전력','대한항공','현대백화점','셀트리온','KB금융','LG화학','아모레퍼시픽','기업은행','현대모비스','대우조선해양','GS건설', 'CJ제일제당','삼성전자']
kospi20[16]
# Out:
# '대우조선해양'

# %%
kospi_missed=['이마트','SK하이닉스','삼성전자']

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.asiae.co.kr/'

# 페이지 이동
driver.get(url)
time.sleep(1)

for kospi in kospi_missed[0:1]: # 요기 수정해서 크롤링하기!
    #돋보기 버튼 누르기
    driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > a').send_keys('\n')
    time.sleep(1)
    # 검색목록에 넣기
    e = driver.find_element_by_css_selector('#search1')
    e.send_keys(kospi)
    # 검색버튼 누르기
    driver.find_element_by_css_selector('#main_wrap > div.main_header > div.top_head > div.area_fstare > div > div > div.search_wrap > form > fieldset > div > input').send_keys('\n')
    time.sleep(1)
    
    #뉴스 목록 선택
    driver.find_element_by_css_selector('#type_news > a > span').click()
    time.sleep(0.5)
    
    #검색옵션 선택
    driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lnb > div > a > span").click()
    time.sleep(0.5)
    
    #기간 필터 클릭 수정##################################################
    Tofrom = driver.find_element_by_xpath('//*[@id="wrap"]/div[2]/div[2]/div/div/ul/li[2]/a/span')
    driver.execute_script("arguments[0].click();", Tofrom)
    time.sleep(0.1)

    #기간 입력 및 적용
    #inputsDate = driver.find_element_by_xpath('//*[@id="sDate"]')
    inputsDate = driver.find_element_by_css_selector('#sDate')
    inputsDate.send_keys('2014.01.01')
    driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").send_keys('\n')
    time.sleep(0.5)
    
    inputeDate = driver.find_element_by_css_selector('#eDate')
    inputeDate.send_keys('2014.08.31')
    driver.find_element_by_css_selector("#ui-datepicker-div > div.ui-datepicker-buttonpane.ui-widget-content > button.ui-datepicker-close.ui-state-default.ui-priority-primary.ui-corner-all").send_keys('\n')
    time.sleep(0.5)
    driver.find_element_by_css_selector("#wrap > div.seo_lnb > div.sch_lst > div > div > div > ul.tcont.tabcont02.on > li.inp_box > div > a").send_keys('\n') 
    time.sleep(0.1)
    
    #article_df 초기화
    article_df = pd.DataFrame(columns = ['Title', 'Date','Category'])
    for section in range(2,12):
        #섹션 변경시 섹션페이지 잘리는 것을 방지
        if section != 2:
            driver.back()
            time.sleep(1)
        #섹션 선택
        driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_btn > a > span').click()
        time.sleep(0.5)
        driver.find_element_by_css_selector('#container > div.content > div > div > h3 > div.ns_wrap > ul > li:nth-child({}) > a'.format(section)).send_keys('\n')
        time.sleep(2)
        # total count를 크롤링해서 전체 페이지 수를 체킹
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')
        #섹션에 뉴스가 없을 경우 다음 섹션으로 이동
        if total_count is None:
            article_df = article_df.append({'Title' : None, 'Date':None, 'Category':section}, ignore_index = True)
            continue
        #페이지 수 구하기
        total_count = int(total_count.string[2:-1].replace(",",""))
        # 페이지가 딱 나눠지게 된다면 +1 을 해주면 안됨
        if total_count%15 != 0:
            pages = total_count//15 + 1
        else :pages = total_count//15
        for page in range(pages):
            # 페이지 바에 대한 셀레늄을 리스트로 가져와서 페이지에 따라 선택
            page_bar = driver.find_elements_by_css_selector('div.paging_comm > span.inner_paging > *')
            # 처음 시작할때는 페이지바 안누르기
            if page != 0:
                if page%10 != 0:
                    page_bar[page%10].click()
                else :
                    page_bar[len(page_bar)-1].click()
            time.sleep(0.5)
            #beautifulsoup으로 크롤링하기
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            leng = soup.body.select('#container > div > div > div > ul')
            a = leng[0].find_all('li')
            for i in a:
                temp_t = i.find('span', class_='tit')
                temp_d =i.find('span',class_='dt_t')
                # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
                article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)
    #파일 csv로 내보내기
    article_df.to_csv('./article_df/selected20/{}_df_2014.csv'.format(kospi))     
    #첫페이지로 이동######수정###########################################
    start_page = driver.find_element_by_xpath('//*[@id="wrap"]/div[1]/div[1]/div/div[1]/h1/a/img')
    driver.execute_script("arguments[0].click();", start_page)

# %%
# 2014년도만 크롤링한 종목 이전 df와 합치기

kospi_missed=['이마트','SK하이닉스','삼성전자']

for kospi in kospi_missed:
    old_data = pd.read_csv('./article_df/{}_df.csv'.format(kospi))
    #print(len(old_data))
    #2020년도 데이터 삭제
    for i in range(len(old_data['Date'])):
        if old_data['Date'][i].startswith('2020')==True:
            old_data.drop(i, inplace=True)

    new_data = pd.read_csv('./article_df/selected20/{}_df_2014.csv'.format(kospi))

    merge_data = pd.concat([old_data,new_data]).sort_values('Date', ascending=False)
    merge_data = merge_data.reset_index(drop=True)

    merge_data.to_csv('./article_df/selected20/{}_df.csv'.format(kospi))
#print(len(old_data), len(new_data), len(merge_data))

# %%
article_df
# Out:
#                                     Title        Date Category
# 0         LGU+, '6·25 무공훈장 주인공 찾기' 캠페인 동참  2020.06.14        2
# 1                  손흥민, 무공훈장 수훈자 찾기 운동 동참  2020.06.10        2
# 2           '조국 증인'으로 싸우는 사이…기업인들만 국감 줄소환  2019.09.24        2
# 3       산자위, '조국 펀드' 관련 익성·웰스씨앤티 대표 증인 채택  2019.09.24        2
# 4          무인이동체 분야 '2019 무인이동체 산업엑스포' 개막  2019.07.10        2
# ...                                   ...         ...      ...
# 4340            널널한 '아이폰8' 예약판매…사뭇 다른 분위기  2017.10.27        4
# 4341    [아이폰8 예판] 불안한 유통점…"갤노트7 반복할 수 없어"  2017.10.27        4
# 4342         하반기 최대어 '아이폰8' 등장…이통사 영업戰 시작  2017.10.27        4
# 4343  '아이폰8' 지원금 받아도 100만원선…상한제 풀려도 '쥐꼬리'  2017.10.27        4
# 4344    LG G6 실패 뼈아팠다…스마트폰 10분기 연속 적자(종합)  2017.10.26        4
#
# [4345 rows x 3 columns]

# %%
# section += 1

# article_df = article_df.append({'Title' : None, 'Date':None, 'Category':section}, ignore_index = True)

# %%
# 오류시 이번 섹션 처음부터 크롤링
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
total_count = soup.body.select_one('#container > div.content > div > div > h3 > span')

#페이지 수 구하기
total_count = int(total_count.string[2:-1].replace(",",""))
if total_count%15 != 0:
    pages = total_count//15 + 1
else :pages = total_count//15

for page in range(pages+1):
    # 페이지 바에 대한 셀레늄을 리스트로 가져와서 페이지에 따라 선택
    page_bar = driver.find_elements_by_css_selector('div.paging_comm > span.inner_paging > *')
    # 처음 시작할때는 페이지바 안누르기
    if page != 0:
        if page%10 != 0:
            page_bar[page%10].click()
        else :
            page_bar[len(page_bar)-1].click()
    time.sleep(0.5)
    #beautifulsoup으로 크롤링하기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    leng = soup.body.select('#container > div > div > div > ul')
    a = leng[0].find_all('li')
    for i in a:
        temp_t = i.find('span', class_='tit')
        temp_d =i.find('span',class_='dt_t')
        # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
        article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)

# %%
article_df.tail(50)
# Out:
#                                              Title        Date Category
# 3247                4대궁ㆍ종묘, 올해 관람객 첫 1000만 명 돌파 눈앞  2016.11.22        9
# 3248                               지갑열리게 만드는 뷰티 신상  2016.09.30        9
# 3249                   지난해 면세점 매출 '후' 1위…샤넬 8위로 추락  2016.02.23        9
# 3250  '한국방문의 해' 중국인들 선호 한국 명품에 '엑소'도 포함…다른 건 뭐뭐 있나  2015.11.07        9
# 3251                       LG생활건강-문화재청, 창경궁 지킴이 협약  2015.10.16        9
# 3252                       LG생활건강, 수려한 새 모델 한효주 발탁  2015.09.15        9
# 3253  '구더기 액상분유' 논란 진실공방, 업체 측 "살아있는 벌레 살아남을 수 없어"  2015.07.18        9
# 3254                      LG생활건강, 튠에이지 듀얼 스핀 스파 출시  2015.07.13        9
# 3255                     LG생활건강, 한·입 내추럴 아로마테라피 출시  2015.07.06        9
# 3256                  LG생활건강, 오휘·양태오 콜라보레이션 한정판 출시  2015.07.01        9
# 3257                     LG생활건강, 비욘드 제주 대나무 수딩젤 출시  2015.06.16        9
# 3258                 유아용품 시장 발담그는 뷰티 '빅2'…中 진출 나서나  2015.06.10        9
# 3259                 더페이스샵, 매월 마지막 금요일은 '더 테라피 데이'  2015.05.29        9
# 3260                         LG생활건강, 보브 모델로 고성희 발탁  2015.05.27        9
# 3261                        더 플라자, 퍼펙트 겟어웨이 패키지 선봬  2015.05.26        9
# 3262                   LG생건 VDL, 카카오프렌즈 콜라보 컬렉션 출시  2015.05.21        9
# 3263                LG생건, '비욘드 메이드 인 제주 미라클 라인' 출시  2015.05.13        9
# 3264                      LG생활건강, 오휘 미라클 아쿠아 5종 출시  2015.05.12        9
# 3265                           블랙야크, 독거노인에 후원물품 전달  2015.05.08        9
# 3266                      더페이스샵, 중국인 소비자 모니터 1기 출범  2015.05.08        9
# 3267                         LG생건·대한아토피협회, 업무협약 체결  2015.05.08        9
# 3268                    LG생활건강, 장애인고용 자회사 설립 협약 체결  2015.05.07        9
# 3269                    요우커 열풍에 한방화장품들마다 '모란꽃' 마케팅  2015.05.06        9
# 3270                   LG생활건강, 네팔 지진 구호 생필품 지원에 나서  2015.05.03        9
# 3271                 LG생활건강, 비욘드 10주년 기념 멤버십 데이 진행  2015.04.30        9
# 3272                     LG생활건강, 후 환유고 헤리티지 에디션 출시  2015.04.29        9
# 3273                [2015브랜드대상] 식물뿌리의 수분·영양 담은 화장품  2015.04.23        9
# 3274                    LG생활건강, 비욘드 새로운 뮤즈에 공승연 발탁  2015.04.17        9
# 3275                     LG생활건강, 엘라스틴 바이오테라피 라인 출시  2015.04.14        9
# 3276                         잇츠스킨, 빅2 앞지른 '달팽이의 힘'  2015.04.09        9
# 3277                     LG생활건강, 온더바디 영 마케터즈 1기 모집  2015.04.09        9
# 3278                  LG생건, 비욘드 히말라야 맑은 크림 기획세트 출시  2015.04.05        9
# 3279              교보문고, 대표작가 10인이 들려주는 '아름다운 말' 전시  2015.02.10        9
# 3280             이민정 4월 출산, 엄태웅 "이민정은 모든 남자들이 좋아해"  2015.01.20        9
# 3281         김태희, 아름다운 얼굴 행사 참여…"김태희의 시간은 거꾸로 흐른다"  2014.10.26        9
# 3282              김태희, 국보급 미모로 가로수길 깜짝 등장에 男心 '흔들'  2014.10.26        9
# 3283      중국인이 뽑은 한국 명품 '엑소'도 명품 대열 합류…"한류 열풍 느껴져"  2014.10.23        9
# 3284                                           NaN         NaN       10
# 3285      [연.방.스] 자연주의 감독과 자연미인 배우의 꿀케미…영화 이어 CF까지  2017.10.27       11
# 3286                           LG컵 국제여자야구대회 28일 폐막  2017.08.28       11
# 3287                         'LG컵 국제여자야구대회' 25일 개막  2017.08.25       11
# 3288             지코 틴트·서예지 악플…연예인들 “가만히 두고 보지 않겠다”  2016.01.21       11
# 3289           지코 측 "무단으로 ‘지코’ 이용해 홍보 LG생활건강 해명하라"  2016.01.20       11
# 3290                     신민아, 소외계층 위해 10억을…'기부 천사'  2015.10.15       11
# 3291             이민정 4월 출산, 엄태웅 "이민정은 모든 남자들이 좋아해"  2015.01.20       11
# 3292       김태희, 아름다운 얼굴 캠페인 참여…여전한 '여신외모'에 시선 '집중'  2014.10.27       11
# 3293       김태희, '아름다운 얼굴' 캠페인 참여…변함없는 여신의 '눈부신 미모'  2014.10.27       11
# 3294         김태희, 아름다운 얼굴 행사 참여…여전한 '눈부신 외모' 관심 집중  2014.10.27       11
# 3295         김태희, 아름다운 얼굴 행사 참여…"김태희의 시간은 거꾸로 흐른다"  2014.10.26       11
# 3296              김태희, 국보급 미모로 가로수길 깜짝 등장에 男心 '흔들'  2014.10.26       11

# %%
# # 오류시 이번 페이지만 수동으로 크롤링 
# # section 바꿔주는거 잊지말기
# html = driver.page_source
# soup = BeautifulSoup(html, 'html.parser')
# leng = soup.body.select('#container > div > div > div > ul')
# a = leng[0].find_all('li')
# for i in a:
#     temp_t = i.find('span', class_='tit')
#     temp_d =i.find('span',class_='dt_t')
#     # category 는 후에 위에 다른 변수에서 설정해서 퍼와야할듯
#     article_df = article_df.append({'Title' : temp_t.a.text.strip(), 'Date':temp_d.string[:10], 'Category':section}, ignore_index = True)

# %%
article_df.to_csv('./article_df/{}_df.csv'.format(kospi))

# %%
article_df
# Out:
#                                                  Title        Date Category
# 0                        우즈베키스탄, 방역 도운 韓전문가에 귀국 항공편 제공  2020.04.23        2
# 1           이낙연 “지역주의 완화로 전 국민께 감동 선사해 달라” TK 찾아 지지 호소  2020.04.13        2
# 2     [영남권 民心은] “예산通 김현권, 의외로 선전” vs “박정희 고향, 무조건 김영식”  2020.04.06        2
# 3                          조코위 대통령, 감천마을 찾아 "부산의 마추픽추"  2019.11.25        2
# 4                      에너지공단, '2019년 우수사업장 인증서 수여식' 개최  2019.11.15        2
# ...                                                ...         ...      ...
# 5017            이이경 "아버지는 전 LG 계열사 대표 이웅범…1원도 받은 적 없어"  2020.02.09       11
# 5018             이이경 금수저설? “편견이고 선입견”...“이상형은 소녀시대 태연”  2017.11.16       11
# 5019       '오뚜기 창업주 손녀'  뮤지컬 배우 함연지, 숨겨진 연예계 '로열패밀리'는?  2017.07.24       11
# 5020                          '라디오스타' 이이경, 검소한 금수저 생활?  2016.03.03       11
# 5021                                               NaN         NaN       10
#
# [5022 rows x 3 columns]
